# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:56, 963KB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 16
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 16:
# Image - Min Value: 8 Max Value: 253
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    output = []
    for sample in x:
        one_hot = np.zeros(10, dtype=int)
        one_hot[sample] = 1
        output.append(one_hot)
    return np.array(output)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shape = list(image_shape)
    shape.insert(0, None)
    return tf.placeholder(tf.float32, shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, None, name="keep_prob")
    # by @arthurcgusmao: is this correct? From the documentation, it seems like leaving
    #                    the shape as None in fact allows for any shape to be passed.
    #                    When passing the shape parameter as () or [] would leave an error here.


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    in_channels = int(x_tensor.shape[-1])
    weights_shape = [conv_ksize[0], conv_ksize[1], in_channels, conv_num_outputs]
    conv_strides_arg = [1, conv_strides[0], conv_strides[1], 1]
    pool_ksize_arg = [1, pool_ksize[0], pool_ksize[1], 1]
    pool_strides_arg = [1, pool_strides[0], pool_strides[1], 1]
    
    # setting the standard deviation to 0.01 guarantees that 
    weights = tf.Variable(tf.truncated_normal(weights_shape, stddev=0.05))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    
    output = tf.nn.conv2d(x_tensor, weights, strides=conv_strides_arg, padding='SAME')
    output = tf.nn.bias_add(output, biases)
    # performing max pooling before the activation function guarantees less calculations are made
    output = tf.nn.max_pool(output, ksize=pool_ksize_arg, strides=pool_strides_arg, padding='SAME')
    output = tf.nn.relu(output)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
import numpy as np # added by @arthurcgusmao -- don't know if allowed

def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape_without_batch_size = x_tensor.get_shape().as_list()[1:]
    dim_1 = np.prod(np.array(shape_without_batch_size))
    return tf.reshape(x_tensor, [-1, dim_1])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dim_1 = x_tensor.get_shape().as_list()[1]
    
    weights = tf.Variable(tf.truncated_normal([dim_1, num_outputs], stddev=0.1))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    output = tf.add(tf.matmul(x_tensor, weights), biases)
    output = tf.nn.relu(output)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dim_1 = x_tensor.get_shape().as_list()[1]
    
    weights = tf.Variable(tf.truncated_normal([dim_1, num_outputs]))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.add(tf.matmul(x_tensor, weights), biases)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = conv2d_maxpool(x, 24, (3, 3), (1, 1), (2, 2), (2, 2)) 
    x = conv2d_maxpool(x, 48, (3, 3), (1, 1), (2, 2), (2, 2))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x = tf.nn.dropout(x, keep_prob)
    x = fully_conn(x, 1000)
    x = fully_conn(x, 100)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x = output(x, 10)
    
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    a = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    c = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    print('Cost: {:>10.4f}, Accuracy: {:>9.6f}'.format(c, a))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512 #2048
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost:     2.1867, Accuracy:  0.230000
# Epoch  2, CIFAR-10 Batch 1:  Cost:     1.8548, Accuracy:  0.349400
# Epoch  3, CIFAR-10 Batch 1:  Cost:     1.6502, Accuracy:  0.421400
# Epoch  4, CIFAR-10 Batch 1:  Cost:     1.4927, Accuracy:  0.456000
# Epoch  5, CIFAR-10 Batch 1:  Cost:     1.3872, Accuracy:  0.490200
# Epoch  6, CIFAR-10 Batch 1:  Cost:     1.2641, Accuracy:  0.504400
# Epoch  7, CIFAR-10 Batch 1:  Cost:     1.1784, Accuracy:  0.520200
# Epoch  8, CIFAR-10 Batch 1:  Cost:     1.1056, Accuracy:  0.530200
# Epoch  9, CIFAR-10 Batch 1:  Cost:     1.0362, Accuracy:  0.535000
# Epoch 10, CIFAR-10 Batch 1:  Cost:     0.9637, Accuracy:  0.545200
# Epoch 11, CIFAR-10 Batch 1:  Cost:     0.9230, Accuracy:  0.544400
# Epoch 12, CIFAR-10 Batch 1:  Cost:     0.8473, Accuracy:  0.560800
# Epoch 13, CIFAR-10 Batch 1:  Cost:     0.7856, Accuracy:  0.574600
# Epoch 14, CIFAR-10 Batch 1:  Cost:     0.7322, Accuracy:  0.578000
# Epoch 15, CIFAR-10 Batch 1:  Cost:     0.6858, Accuracy:  0.589000
# Epoch 16, CIFAR-10 Batch 1:  Cost:     0.6466, Accuracy:  0.584600
# Epoch 17, CIFAR-10 Batch 1:  Cost:     0.5907, Accuracy:  0.595600
# Epoch 18, CIFAR-10 Batch 1:  Cost:     0.5562, Accuracy:  0.594800
# Epoch 19, CIFAR-10 Batch 1:  Cost:     0.4970, Accuracy:  0.597400
# Epoch 20, CIFAR-10 Batch 1:  Cost:     0.4798, Accuracy:  0.601200
# Epoch 21, CIFAR-10 Batch 1:  Cost:     0.4417, Accuracy:  0.602600
# Epoch 22, CIFAR-10 Batch 1:  Cost:     0.4071, Accuracy:  0.596200
# Epoch 23, CIFAR-10 Batch 1:  Cost:     0.3746, Accuracy:  0.608600
# Epoch 24, CIFAR-10 Batch 1:  Cost:     0.4029, Accuracy:  0.582200
# Epoch 25, CIFAR-10 Batch 1:  Cost:     0.3413, Accuracy:  0.604000
# Epoch 26, CIFAR-10 Batch 1:  Cost:     0.3576, Accuracy:  0.598000
# Epoch 27, CIFAR-10 Batch 1:  Cost:     0.3019, Accuracy:  0.607400
# Epoch 28, CIFAR-10 Batch 1:  Cost:     0.3051, Accuracy:  0.607000
# Epoch 29, CIFAR-10 Batch 1:  Cost:     0.2470, Accuracy:  0.619400
# Epoch 30, CIFAR-10 Batch 1:  Cost:     0.2335, Accuracy:  0.603400
# Epoch 31, CIFAR-10 Batch 1:  Cost:     0.1848, Accuracy:  0.612200
# Epoch 32, CIFAR-10 Batch 1:  Cost:     0.1700, Accuracy:  0.616200
# Epoch 33, CIFAR-10 Batch 1:  Cost:     0.1444, Accuracy:  0.623400
# Epoch 34, CIFAR-10 Batch 1:  Cost:     0.1379, Accuracy:  0.618200
# Epoch 35, CIFAR-10 Batch 1:  Cost:     0.1413, Accuracy:  0.604600
# Epoch 36, CIFAR-10 Batch 1:  Cost:     0.1227, Accuracy:  0.608400
# Epoch 37, CIFAR-10 Batch 1:  Cost:     0.1081, Accuracy:  0.612400
# Epoch 38, CIFAR-10 Batch 1:  Cost:     0.0808, Accuracy:  0.620000
# Epoch 39, CIFAR-10 Batch 1:  Cost:     0.0864, Accuracy:  0.610400
# Epoch 40, CIFAR-10 Batch 1:  Cost:     0.0760, Accuracy:  0.615800
# Epoch 41, CIFAR-10 Batch 1:  Cost:     0.0768, Accuracy:  0.613000
# Epoch 42, CIFAR-10 Batch 1:  Cost:     0.0492, Accuracy:  0.620800
# Epoch 43, CIFAR-10 Batch 1:  Cost:     0.0584, Accuracy:  0.618000
# Epoch 44, CIFAR-10 Batch 1:  Cost:     0.0525, Accuracy:  0.606600
# Epoch 45, CIFAR-10 Batch 1:  Cost:     0.0362, Accuracy:  0.615600
# Epoch 46, CIFAR-10 Batch 1:  Cost:     0.0344, Accuracy:  0.618800
# Epoch 47, CIFAR-10 Batch 1:  Cost:     0.0277, Accuracy:  0.627800
# Epoch 48, CIFAR-10 Batch 1:  Cost:     0.0380, Accuracy:  0.610200
# Epoch 49, CIFAR-10 Batch 1:  Cost:     0.0431, Accuracy:  0.610600
# Epoch 50, CIFAR-10 Batch 1:  Cost:     0.0329, Accuracy:  0.612200
# Epoch 51, CIFAR-10 Batch 1:  Cost:     0.0435, Accuracy:  0.608600
# Epoch 52, CIFAR-10 Batch 1:  Cost:     0.0217, Accuracy:  0.624000
# Epoch 53, CIFAR-10 Batch 1:  Cost:     0.0295, Accuracy:  0.604400
# Epoch 54, CIFAR-10 Batch 1:  Cost:     0.0326, Accuracy:  0.598200
# Epoch 55, CIFAR-10 Batch 1:  Cost:     0.0217, Accuracy:  0.606000
# Epoch 56, CIFAR-10 Batch 1:  Cost:     0.0187, Accuracy:  0.620400
# Epoch 57, CIFAR-10 Batch 1:  Cost:     0.0110, Accuracy:  0.624200
# Epoch 58, CIFAR-10 Batch 1:  Cost:     0.0122, Accuracy:  0.615800
# Epoch 59, CIFAR-10 Batch 1:  Cost:     0.0093, Accuracy:  0.612200
# Epoch 60, CIFAR-10 Batch 1:  Cost:     0.0104, Accuracy:  0.615600
# Epoch 61, CIFAR-10 Batch 1:  Cost:     0.0067, Accuracy:  0.614200
# Epoch 62, CIFAR-10 Batch 1:  Cost:     0.0068, Accuracy:  0.623400
# Epoch 63, CIFAR-10 Batch 1:  Cost:     0.0058, Accuracy:  0.623400
# Epoch 64, CIFAR-10 Batch 1:  Cost:     0.0056, Accuracy:  0.621200
# Epoch 65, CIFAR-10 Batch 1:  Cost:     0.0053, Accuracy:  0.613600
# Epoch 66, CIFAR-10 Batch 1:  Cost:     0.0039, Accuracy:  0.622800
# Epoch 67, CIFAR-10 Batch 1:  Cost:     0.0031, Accuracy:  0.630600
# Epoch 68, CIFAR-10 Batch 1:  Cost:     0.0033, Accuracy:  0.626000
# Epoch 69, CIFAR-10 Batch 1:  Cost:     0.0048, Accuracy:  0.623800
# Epoch 70, CIFAR-10 Batch 1:  Cost:     0.0094, Accuracy:  0.610400
# Epoch 71, CIFAR-10 Batch 1:  Cost:     0.0046, Accuracy:  0.630400
# Epoch 72, CIFAR-10 Batch 1:  Cost:     0.0027, Accuracy:  0.627400
# Epoch 73, CIFAR-10 Batch 1:  Cost:     0.0026, Accuracy:  0.629800
# Epoch 74, CIFAR-10 Batch 1:  Cost:     0.0027, Accuracy:  0.617000
# Epoch 75, CIFAR-10 Batch 1:  Cost:     0.0017, Accuracy:  0.629000
# Epoch 76, CIFAR-10 Batch 1:  Cost:     0.0023, Accuracy:  0.625000
# Epoch 77, CIFAR-10 Batch 1:  Cost:     0.0019, Accuracy:  0.630800
# Epoch 78, CIFAR-10 Batch 1:  Cost:     0.0021, Accuracy:  0.625200
# Epoch 79, CIFAR-10 Batch 1:  Cost:     0.0017, Accuracy:  0.631000
# Epoch 80, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.611800
# Epoch 81, CIFAR-10 Batch 1:  Cost:     0.0022, Accuracy:  0.616200
# Epoch 82, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.611800
# Epoch 83, CIFAR-10 Batch 1:  Cost:     0.0039, Accuracy:  0.613600
# Epoch 84, CIFAR-10 Batch 1:  Cost:     0.0014, Accuracy:  0.621600
# Epoch 85, CIFAR-10 Batch 1:  Cost:     0.0017, Accuracy:  0.623400
# Epoch 86, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.621200
# Epoch 87, CIFAR-10 Batch 1:  Cost:     0.0021, Accuracy:  0.624400
# Epoch 88, CIFAR-10 Batch 1:  Cost:     0.0024, Accuracy:  0.627200
# Epoch 89, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.620400
# Epoch 90, CIFAR-10 Batch 1:  Cost:     0.0013, Accuracy:  0.631400
# Epoch 91, CIFAR-10 Batch 1:  Cost:     0.0016, Accuracy:  0.638200
# Epoch 92, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.626800
# Epoch 93, CIFAR-10 Batch 1:  Cost:     0.0008, Accuracy:  0.636000
# Epoch 94, CIFAR-10 Batch 1:  Cost:     0.0012, Accuracy:  0.629000
# Epoch 95, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.630200
# Epoch 96, CIFAR-10 Batch 1:  Cost:     0.0013, Accuracy:  0.634000
# Epoch 97, CIFAR-10 Batch 1:  Cost:     0.0017, Accuracy:  0.630000
# Epoch 98, CIFAR-10 Batch 1:  Cost:     0.0014, Accuracy:  0.638000
# Epoch 99, CIFAR-10 Batch 1:  Cost:     0.0018, Accuracy:  0.629000
# Epoch 100, CIFAR-10 Batch 1:  Cost:     0.0009, Accuracy:  0.630200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost:     2.1046, Accuracy:  0.229600
# Epoch  1, CIFAR-10 Batch 2:  Cost:     1.7445, Accuracy:  0.350800
# Epoch  1, CIFAR-10 Batch 3:  Cost:     1.5209, Accuracy:  0.411000
# Epoch  1, CIFAR-10 Batch 4:  Cost:     1.4595, Accuracy:  0.442600
# Epoch  1, CIFAR-10 Batch 5:  Cost:     1.4436, Accuracy:  0.469800
# Epoch  2, CIFAR-10 Batch 1:  Cost:     1.4175, Accuracy:  0.503400
# Epoch  2, CIFAR-10 Batch 2:  Cost:     1.2804, Accuracy:  0.527200
# Epoch  2, CIFAR-10 Batch 3:  Cost:     1.1827, Accuracy:  0.515600
# Epoch  2, CIFAR-10 Batch 4:  Cost:     1.1800, Accuracy:  0.535800
# Epoch  2, CIFAR-10 Batch 5:  Cost:     1.2253, Accuracy:  0.543200
# Epoch  3, CIFAR-10 Batch 1:  Cost:     1.2433, Accuracy:  0.553600
# Epoch  3, CIFAR-10 Batch 2:  Cost:     1.1090, Accuracy:  0.568000
# Epoch  3, CIFAR-10 Batch 3:  Cost:     1.0753, Accuracy:  0.560800
# Epoch  3, CIFAR-10 Batch 4:  Cost:     1.0219, Accuracy:  0.580600
# Epoch  3, CIFAR-10 Batch 5:  Cost:     1.1002, Accuracy:  0.581800
# Epoch  4, CIFAR-10 Batch 1:  Cost:     1.1152, Accuracy:  0.596400
# Epoch  4, CIFAR-10 Batch 2:  Cost:     1.0138, Accuracy:  0.610800
# Epoch  4, CIFAR-10 Batch 3:  Cost:     0.9502, Accuracy:  0.599200
# Epoch  4, CIFAR-10 Batch 4:  Cost:     0.9225, Accuracy:  0.606200
# Epoch  4, CIFAR-10 Batch 5:  Cost:     0.9398, Accuracy:  0.611800
# Epoch  5, CIFAR-10 Batch 1:  Cost:     1.0234, Accuracy:  0.624800
# Epoch  5, CIFAR-10 Batch 2:  Cost:     0.9154, Accuracy:  0.627800
# Epoch  5, CIFAR-10 Batch 3:  Cost:     0.8878, Accuracy:  0.614600
# Epoch  5, CIFAR-10 Batch 4:  Cost:     0.8470, Accuracy:  0.633200
# Epoch  5, CIFAR-10 Batch 5:  Cost:     0.8611, Accuracy:  0.632000
# Epoch  6, CIFAR-10 Batch 1:  Cost:     0.9072, Accuracy:  0.647000
# Epoch  6, CIFAR-10 Batch 2:  Cost:     0.8288, Accuracy:  0.643200
# Epoch  6, CIFAR-10 Batch 3:  Cost:     0.7872, Accuracy:  0.633200
# Epoch  6, CIFAR-10 Batch 4:  Cost:     0.7511, Accuracy:  0.650600
# Epoch  6, CIFAR-10 Batch 5:  Cost:     0.7476, Accuracy:  0.656000
# Epoch  7, CIFAR-10 Batch 1:  Cost:     0.8615, Accuracy:  0.655000
# Epoch  7, CIFAR-10 Batch 2:  Cost:     0.7636, Accuracy:  0.657200
# Epoch  7, CIFAR-10 Batch 3:  Cost:     0.7402, Accuracy:  0.643400
# Epoch  7, CIFAR-10 Batch 4:  Cost:     0.7180, Accuracy:  0.656200
# Epoch  7, CIFAR-10 Batch 5:  Cost:     0.6858, Accuracy:  0.662600
# Epoch  8, CIFAR-10 Batch 1:  Cost:     0.7398, Accuracy:  0.673800
# Epoch  8, CIFAR-10 Batch 2:  Cost:     0.6754, Accuracy:  0.668600
# Epoch  8, CIFAR-10 Batch 3:  Cost:     0.6511, Accuracy:  0.655800
# Epoch  8, CIFAR-10 Batch 4:  Cost:     0.6255, Accuracy:  0.675200
# Epoch  8, CIFAR-10 Batch 5:  Cost:     0.5994, Accuracy:  0.678400
# Epoch  9, CIFAR-10 Batch 1:  Cost:     0.6823, Accuracy:  0.682200
# Epoch  9, CIFAR-10 Batch 2:  Cost:     0.6358, Accuracy:  0.672400
# Epoch  9, CIFAR-10 Batch 3:  Cost:     0.5865, Accuracy:  0.674200
# Epoch  9, CIFAR-10 Batch 4:  Cost:     0.5910, Accuracy:  0.682800
# Epoch  9, CIFAR-10 Batch 5:  Cost:     0.5471, Accuracy:  0.691200
# Epoch 10, CIFAR-10 Batch 1:  Cost:     0.6165, Accuracy:  0.692600
# Epoch 10, CIFAR-10 Batch 2:  Cost:     0.6298, Accuracy:  0.654600
# Epoch 10, CIFAR-10 Batch 3:  Cost:     0.5504, Accuracy:  0.684000
# Epoch 10, CIFAR-10 Batch 4:  Cost:     0.5385, Accuracy:  0.686000
# Epoch 10, CIFAR-10 Batch 5:  Cost:     0.5004, Accuracy:  0.695400
# Epoch 11, CIFAR-10 Batch 1:  Cost:     0.5763, Accuracy:  0.692400
# Epoch 11, CIFAR-10 Batch 2:  Cost:     0.5437, Accuracy:  0.682600
# Epoch 11, CIFAR-10 Batch 3:  Cost:     0.5268, Accuracy:  0.685400
# Epoch 11, CIFAR-10 Batch 4:  Cost:     0.4632, Accuracy:  0.703000
# Epoch 11, CIFAR-10 Batch 5:  Cost:     0.4349, Accuracy:  0.697600
# Epoch 12, CIFAR-10 Batch 1:  Cost:     0.5097, Accuracy:  0.706000
# Epoch 12, CIFAR-10 Batch 2:  Cost:     0.4995, Accuracy:  0.692800
# Epoch 12, CIFAR-10 Batch 3:  Cost:     0.4932, Accuracy:  0.686000
# Epoch 12, CIFAR-10 Batch 4:  Cost:     0.3980, Accuracy:  0.713400
# Epoch 12, CIFAR-10 Batch 5:  Cost:     0.4174, Accuracy:  0.715200
# Epoch 13, CIFAR-10 Batch 1:  Cost:     0.4426, Accuracy:  0.714200
# Epoch 13, CIFAR-10 Batch 2:  Cost:     0.4387, Accuracy:  0.713600
# Epoch 13, CIFAR-10 Batch 3:  Cost:     0.3970, Accuracy:  0.705200
# Epoch 13, CIFAR-10 Batch 4:  Cost:     0.4200, Accuracy:  0.699000
# Epoch 13, CIFAR-10 Batch 5:  Cost:     0.3895, Accuracy:  0.710400
# Epoch 14, CIFAR-10 Batch 1:  Cost:     0.4012, Accuracy:  0.721000
# Epoch 14, CIFAR-10 Batch 2:  Cost:     0.3633, Accuracy:  0.723600
# Epoch 14, CIFAR-10 Batch 3:  Cost:     0.3671, Accuracy:  0.705000
# Epoch 14, CIFAR-10 Batch 4:  Cost:     0.3055, Accuracy:  0.717800
# Epoch 14, CIFAR-10 Batch 5:  Cost:     0.3286, Accuracy:  0.725200
# Epoch 15, CIFAR-10 Batch 1:  Cost:     0.3396, Accuracy:  0.723000
# Epoch 15, CIFAR-10 Batch 2:  Cost:     0.3441, Accuracy:  0.721200
# Epoch 15, CIFAR-10 Batch 3:  Cost:     0.3151, Accuracy:  0.710600
# Epoch 15, CIFAR-10 Batch 4:  Cost:     0.2939, Accuracy:  0.704600
# Epoch 15, CIFAR-10 Batch 5:  Cost:     0.2939, Accuracy:  0.729000
# Epoch 16, CIFAR-10 Batch 1:  Cost:     0.2918, Accuracy:  0.726400
# Epoch 16, CIFAR-10 Batch 2:  Cost:     0.2993, Accuracy:  0.724400
# Epoch 16, CIFAR-10 Batch 3:  Cost:     0.2708, Accuracy:  0.722000
# Epoch 16, CIFAR-10 Batch 4:  Cost:     0.2281, Accuracy:  0.727800
# Epoch 16, CIFAR-10 Batch 5:  Cost:     0.2570, Accuracy:  0.722800
# Epoch 17, CIFAR-10 Batch 1:  Cost:     0.2709, Accuracy:  0.728000
# Epoch 17, CIFAR-10 Batch 2:  Cost:     0.2550, Accuracy:  0.728400
# Epoch 17, CIFAR-10 Batch 3:  Cost:     0.2349, Accuracy:  0.716600
# Epoch 17, CIFAR-10 Batch 4:  Cost:     0.2321, Accuracy:  0.711800
# Epoch 17, CIFAR-10 Batch 5:  Cost:     0.2196, Accuracy:  0.719000
# Epoch 18, CIFAR-10 Batch 1:  Cost:     0.2337, Accuracy:  0.733800
# Epoch 18, CIFAR-10 Batch 2:  Cost:     0.2561, Accuracy:  0.723200
# Epoch 18, CIFAR-10 Batch 3:  Cost:     0.1907, Accuracy:  0.738200
# Epoch 18, CIFAR-10 Batch 4:  Cost:     0.1876, Accuracy:  0.726400
# Epoch 18, CIFAR-10 Batch 5:  Cost:     0.1985, Accuracy:  0.714000
# Epoch 19, CIFAR-10 Batch 1:  Cost:     0.2143, Accuracy:  0.725600
# Epoch 19, CIFAR-10 Batch 2:  Cost:     0.2108, Accuracy:  0.719000
# Epoch 19, CIFAR-10 Batch 3:  Cost:     0.1771, Accuracy:  0.732800
# Epoch 19, CIFAR-10 Batch 4:  Cost:     0.1506, Accuracy:  0.738200
# Epoch 19, CIFAR-10 Batch 5:  Cost:     0.1820, Accuracy:  0.714400
# Epoch 20, CIFAR-10 Batch 1:  Cost:     0.1781, Accuracy:  0.738000
# Epoch 20, CIFAR-10 Batch 2:  Cost:     0.2042, Accuracy:  0.703400
# Epoch 20, CIFAR-10 Batch 3:  Cost:     0.1544, Accuracy:  0.730600
# Epoch 20, CIFAR-10 Batch 4:  Cost:     0.1335, Accuracy:  0.730800
# Epoch 20, CIFAR-10 Batch 5:  Cost:     0.1460, Accuracy:  0.724200
# Epoch 21, CIFAR-10 Batch 1:  Cost:     0.1613, Accuracy:  0.732400
# Epoch 21, CIFAR-10 Batch 2:  Cost:     0.1792, Accuracy:  0.716800
# Epoch 21, CIFAR-10 Batch 3:  Cost:     0.1334, Accuracy:  0.727000
# Epoch 21, CIFAR-10 Batch 4:  Cost:     0.1258, Accuracy:  0.721800
# Epoch 21, CIFAR-10 Batch 5:  Cost:     0.1232, Accuracy:  0.732400
# Epoch 22, CIFAR-10 Batch 1:  Cost:     0.1270, Accuracy:  0.732600
# Epoch 22, CIFAR-10 Batch 2:  Cost:     0.1803, Accuracy:  0.713200
# Epoch 22, CIFAR-10 Batch 3:  Cost:     0.1326, Accuracy:  0.730200
# Epoch 22, CIFAR-10 Batch 4:  Cost:     0.1059, Accuracy:  0.729600
# Epoch 22, CIFAR-10 Batch 5:  Cost:     0.1126, Accuracy:  0.724400
# Epoch 23, CIFAR-10 Batch 1:  Cost:     0.1290, Accuracy:  0.727000
# Epoch 23, CIFAR-10 Batch 2:  Cost:     0.1447, Accuracy:  0.716000
# Epoch 23, CIFAR-10 Batch 3:  Cost:     0.0994, Accuracy:  0.734400
# Epoch 23, CIFAR-10 Batch 4:  Cost:     0.0846, Accuracy:  0.741000
# Epoch 23, CIFAR-10 Batch 5:  Cost:     0.0992, Accuracy:  0.738800
# Epoch 24, CIFAR-10 Batch 1:  Cost:     0.1203, Accuracy:  0.735000
# Epoch 24, CIFAR-10 Batch 2:  Cost:     0.1403, Accuracy:  0.716800
# Epoch 24, CIFAR-10 Batch 3:  Cost:     0.1190, Accuracy:  0.716000
# Epoch 24, CIFAR-10 Batch 4:  Cost:     0.0870, Accuracy:  0.732600
# Epoch 24, CIFAR-10 Batch 5:  Cost:     0.1024, Accuracy:  0.742600
# Epoch 25, CIFAR-10 Batch 1:  Cost:     0.1006, Accuracy:  0.739400
# Epoch 25, CIFAR-10 Batch 2:  Cost:     0.1109, Accuracy:  0.719200
# Epoch 25, CIFAR-10 Batch 3:  Cost:     0.0746, Accuracy:  0.734000
# Epoch 25, CIFAR-10 Batch 4:  Cost:     0.0683, Accuracy:  0.735800
# Epoch 25, CIFAR-10 Batch 5:  Cost:     0.0792, Accuracy:  0.743000
# Epoch 26, CIFAR-10 Batch 1:  Cost:     0.0875, Accuracy:  0.735000
# Epoch 26, CIFAR-10 Batch 2:  Cost:     0.0800, Accuracy:  0.733200
# Epoch 26, CIFAR-10 Batch 3:  Cost:     0.0661, Accuracy:  0.733600
# Epoch 26, CIFAR-10 Batch 4:  Cost:     0.0652, Accuracy:  0.737600
# Epoch 26, CIFAR-10 Batch 5:  Cost:     0.0777, Accuracy:  0.730600
# Epoch 27, CIFAR-10 Batch 1:  Cost:     0.0720, Accuracy:  0.726200
# Epoch 27, CIFAR-10 Batch 2:  Cost:     0.0613, Accuracy:  0.738800
# Epoch 27, CIFAR-10 Batch 3:  Cost:     0.0509, Accuracy:  0.734800
# Epoch 27, CIFAR-10 Batch 4:  Cost:     0.0532, Accuracy:  0.740400
# Epoch 27, CIFAR-10 Batch 5:  Cost:     0.0802, Accuracy:  0.729600
# Epoch 28, CIFAR-10 Batch 1:  Cost:     0.0594, Accuracy:  0.729000
# Epoch 28, CIFAR-10 Batch 2:  Cost:     0.0563, Accuracy:  0.739200
# Epoch 28, CIFAR-10 Batch 3:  Cost:     0.0378, Accuracy:  0.745000
# Epoch 28, CIFAR-10 Batch 4:  Cost:     0.0550, Accuracy:  0.734600
# Epoch 28, CIFAR-10 Batch 5:  Cost:     0.0403, Accuracy:  0.740200
# Epoch 29, CIFAR-10 Batch 1:  Cost:     0.0408, Accuracy:  0.734000
# Epoch 29, CIFAR-10 Batch 2:  Cost:     0.0559, Accuracy:  0.727200
# Epoch 29, CIFAR-10 Batch 3:  Cost:     0.0375, Accuracy:  0.746400
# Epoch 29, CIFAR-10 Batch 4:  Cost:     0.0421, Accuracy:  0.738000
# Epoch 29, CIFAR-10 Batch 5:  Cost:     0.0387, Accuracy:  0.744200
# Epoch 30, CIFAR-10 Batch 1:  Cost:     0.0360, Accuracy:  0.730000
# Epoch 30, CIFAR-10 Batch 2:  Cost:     0.0449, Accuracy:  0.734800
# Epoch 30, CIFAR-10 Batch 3:  Cost:     0.0408, Accuracy:  0.734200
# Epoch 30, CIFAR-10 Batch 4:  Cost:     0.0349, Accuracy:  0.738000
# Epoch 30, CIFAR-10 Batch 5:  Cost:     0.0370, Accuracy:  0.737400
# Epoch 31, CIFAR-10 Batch 1:  Cost:     0.0324, Accuracy:  0.736400
# Epoch 31, CIFAR-10 Batch 2:  Cost:     0.0405, Accuracy:  0.730400
# Epoch 31, CIFAR-10 Batch 3:  Cost:     0.0339, Accuracy:  0.739000
# Epoch 31, CIFAR-10 Batch 4:  Cost:     0.0372, Accuracy:  0.738400
# Epoch 31, CIFAR-10 Batch 5:  Cost:     0.0402, Accuracy:  0.729800
# Epoch 32, CIFAR-10 Batch 1:  Cost:     0.0302, Accuracy:  0.729400
# Epoch 32, CIFAR-10 Batch 2:  Cost:     0.0289, Accuracy:  0.733000
# Epoch 32, CIFAR-10 Batch 3:  Cost:     0.0332, Accuracy:  0.735800
# Epoch 32, CIFAR-10 Batch 4:  Cost:     0.0416, Accuracy:  0.725400
# Epoch 32, CIFAR-10 Batch 5:  Cost:     0.0399, Accuracy:  0.732400
# Epoch 33, CIFAR-10 Batch 1:  Cost:     0.0295, Accuracy:  0.735400
# Epoch 33, CIFAR-10 Batch 2:  Cost:     0.0331, Accuracy:  0.739400
# Epoch 33, CIFAR-10 Batch 3:  Cost:     0.0300, Accuracy:  0.727400
# Epoch 33, CIFAR-10 Batch 4:  Cost:     0.0386, Accuracy:  0.730000
# Epoch 33, CIFAR-10 Batch 5:  Cost:     0.0257, Accuracy:  0.745000
# Epoch 34, CIFAR-10 Batch 1:  Cost:     0.0230, Accuracy:  0.724000
# Epoch 34, CIFAR-10 Batch 2:  Cost:     0.0230, Accuracy:  0.740000
# Epoch 34, CIFAR-10 Batch 3:  Cost:     0.0248, Accuracy:  0.730800
# Epoch 34, CIFAR-10 Batch 4:  Cost:     0.0248, Accuracy:  0.735600
# Epoch 34, CIFAR-10 Batch 5:  Cost:     0.0216, Accuracy:  0.742400
# Epoch 35, CIFAR-10 Batch 1:  Cost:     0.0259, Accuracy:  0.725000
# Epoch 35, CIFAR-10 Batch 2:  Cost:     0.0224, Accuracy:  0.734400
# Epoch 35, CIFAR-10 Batch 3:  Cost:     0.0260, Accuracy:  0.729400
# Epoch 35, CIFAR-10 Batch 4:  Cost:     0.0162, Accuracy:  0.746400
# Epoch 35, CIFAR-10 Batch 5:  Cost:     0.0147, Accuracy:  0.742800
# Epoch 36, CIFAR-10 Batch 1:  Cost:     0.0162, Accuracy:  0.731400
# Epoch 36, CIFAR-10 Batch 2:  Cost:     0.0168, Accuracy:  0.737400
# Epoch 36, CIFAR-10 Batch 3:  Cost:     0.0144, Accuracy:  0.739400
# Epoch 36, CIFAR-10 Batch 4:  Cost:     0.0175, Accuracy:  0.742400
# Epoch 36, CIFAR-10 Batch 5:  Cost:     0.0163, Accuracy:  0.746600
# Epoch 37, CIFAR-10 Batch 1:  Cost:     0.0124, Accuracy:  0.746200
# Epoch 37, CIFAR-10 Batch 2:  Cost:     0.0160, Accuracy:  0.740600
# Epoch 37, CIFAR-10 Batch 3:  Cost:     0.0184, Accuracy:  0.728600
# Epoch 37, CIFAR-10 Batch 4:  Cost:     0.0128, Accuracy:  0.742600
# Epoch 37, CIFAR-10 Batch 5:  Cost:     0.0123, Accuracy:  0.752000
# Epoch 38, CIFAR-10 Batch 1:  Cost:     0.0113, Accuracy:  0.743200
# Epoch 38, CIFAR-10 Batch 2:  Cost:     0.0147, Accuracy:  0.735800
# Epoch 38, CIFAR-10 Batch 3:  Cost:     0.0136, Accuracy:  0.737800
# Epoch 38, CIFAR-10 Batch 4:  Cost:     0.0167, Accuracy:  0.739600
# Epoch 38, CIFAR-10 Batch 5:  Cost:     0.0113, Accuracy:  0.737000
# Epoch 39, CIFAR-10 Batch 1:  Cost:     0.0089, Accuracy:  0.734200
# Epoch 39, CIFAR-10 Batch 2:  Cost:     0.0143, Accuracy:  0.730600
# Epoch 39, CIFAR-10 Batch 3:  Cost:     0.0155, Accuracy:  0.746800
# Epoch 39, CIFAR-10 Batch 4:  Cost:     0.0128, Accuracy:  0.741000
# Epoch 39, CIFAR-10 Batch 5:  Cost:     0.0140, Accuracy:  0.734800
# Epoch 40, CIFAR-10 Batch 1:  Cost:     0.0126, Accuracy:  0.734400
# Epoch 40, CIFAR-10 Batch 2:  Cost:     0.0106, Accuracy:  0.744400
# Epoch 40, CIFAR-10 Batch 3:  Cost:     0.0131, Accuracy:  0.741200
# Epoch 40, CIFAR-10 Batch 4:  Cost:     0.0110, Accuracy:  0.744000
# Epoch 40, CIFAR-10 Batch 5:  Cost:     0.0110, Accuracy:  0.747800
# Epoch 41, CIFAR-10 Batch 1:  Cost:     0.0097, Accuracy:  0.739400
# Epoch 41, CIFAR-10 Batch 2:  Cost:     0.0087, Accuracy:  0.743200
# Epoch 41, CIFAR-10 Batch 3:  Cost:     0.0150, Accuracy:  0.734800
# Epoch 41, CIFAR-10 Batch 4:  Cost:     0.0067, Accuracy:  0.744800
# Epoch 41, CIFAR-10 Batch 5:  Cost:     0.0084, Accuracy:  0.748600
# Epoch 42, CIFAR-10 Batch 1:  Cost:     0.0113, Accuracy:  0.734400
# Epoch 42, CIFAR-10 Batch 2:  Cost:     0.0088, Accuracy:  0.740400
# Epoch 42, CIFAR-10 Batch 3:  Cost:     0.0088, Accuracy:  0.735800
# Epoch 42, CIFAR-10 Batch 4:  Cost:     0.0133, Accuracy:  0.737200
# Epoch 42, CIFAR-10 Batch 5:  Cost:     0.0107, Accuracy:  0.736600
# Epoch 43, CIFAR-10 Batch 1:  Cost:     0.0072, Accuracy:  0.741200
# Epoch 43, CIFAR-10 Batch 2:  Cost:     0.0070, Accuracy:  0.739200
# Epoch 43, CIFAR-10 Batch 3:  Cost:     0.0100, Accuracy:  0.741400
# Epoch 43, CIFAR-10 Batch 4:  Cost:     0.0079, Accuracy:  0.737000
# Epoch 43, CIFAR-10 Batch 5:  Cost:     0.0063, Accuracy:  0.746200
# Epoch 44, CIFAR-10 Batch 1:  Cost:     0.0071, Accuracy:  0.738000
# Epoch 44, CIFAR-10 Batch 2:  Cost:     0.0076, Accuracy:  0.738000
# Epoch 44, CIFAR-10 Batch 3:  Cost:     0.0075, Accuracy:  0.736600
# Epoch 44, CIFAR-10 Batch 4:  Cost:     0.0085, Accuracy:  0.737800
# Epoch 44, CIFAR-10 Batch 5:  Cost:     0.0112, Accuracy:  0.741800
# Epoch 45, CIFAR-10 Batch 1:  Cost:     0.0094, Accuracy:  0.737400
# Epoch 45, CIFAR-10 Batch 2:  Cost:     0.0064, Accuracy:  0.738600
# Epoch 45, CIFAR-10 Batch 3:  Cost:     0.0071, Accuracy:  0.738800
# Epoch 45, CIFAR-10 Batch 4:  Cost:     0.0084, Accuracy:  0.734000
# Epoch 45, CIFAR-10 Batch 5:  Cost:     0.0134, Accuracy:  0.731200
# Epoch 46, CIFAR-10 Batch 1:  Cost:     0.0090, Accuracy:  0.722200
# Epoch 46, CIFAR-10 Batch 2:  Cost:     0.0061, Accuracy:  0.736400
# Epoch 46, CIFAR-10 Batch 3:  Cost:     0.0076, Accuracy:  0.735800
# Epoch 46, CIFAR-10 Batch 4:  Cost:     0.0092, Accuracy:  0.736000
# Epoch 46, CIFAR-10 Batch 5:  Cost:     0.0125, Accuracy:  0.741800
# Epoch 47, CIFAR-10 Batch 1:  Cost:     0.0071, Accuracy:  0.725000
# Epoch 47, CIFAR-10 Batch 2:  Cost:     0.0065, Accuracy:  0.736200
# Epoch 47, CIFAR-10 Batch 3:  Cost:     0.0056, Accuracy:  0.741400
# Epoch 47, CIFAR-10 Batch 4:  Cost:     0.0061, Accuracy:  0.729600
# Epoch 47, CIFAR-10 Batch 5:  Cost:     0.0052, Accuracy:  0.739000
# Epoch 48, CIFAR-10 Batch 1:  Cost:     0.0036, Accuracy:  0.739800
# Epoch 48, CIFAR-10 Batch 2:  Cost:     0.0046, Accuracy:  0.731800
# Epoch 48, CIFAR-10 Batch 3:  Cost:     0.0078, Accuracy:  0.738800
# Epoch 48, CIFAR-10 Batch 4:  Cost:     0.0051, Accuracy:  0.741200
# Epoch 48, CIFAR-10 Batch 5:  Cost:     0.0048, Accuracy:  0.746000
# Epoch 49, CIFAR-10 Batch 1:  Cost:     0.0042, Accuracy:  0.735200
# Epoch 49, CIFAR-10 Batch 2:  Cost:     0.0057, Accuracy:  0.745600
# Epoch 49, CIFAR-10 Batch 3:  Cost:     0.0036, Accuracy:  0.743200
# Epoch 49, CIFAR-10 Batch 4:  Cost:     0.0045, Accuracy:  0.737800
# Epoch 49, CIFAR-10 Batch 5:  Cost:     0.0056, Accuracy:  0.732400
# Epoch 50, CIFAR-10 Batch 1:  Cost:     0.0142, Accuracy:  0.736600
# Epoch 50, CIFAR-10 Batch 2:  Cost:     0.0043, Accuracy:  0.744200
# Epoch 50, CIFAR-10 Batch 3:  Cost:     0.0062, Accuracy:  0.743600
# Epoch 50, CIFAR-10 Batch 4:  Cost:     0.0065, Accuracy:  0.745200
# Epoch 50, CIFAR-10 Batch 5:  Cost:     0.0100, Accuracy:  0.724600
# Epoch 51, CIFAR-10 Batch 1:  Cost:     0.0042, Accuracy:  0.735200
# Epoch 51, CIFAR-10 Batch 2:  Cost:     0.0045, Accuracy:  0.744200
# Epoch 51, CIFAR-10 Batch 3:  Cost:     0.0051, Accuracy:  0.729200
# Epoch 51, CIFAR-10 Batch 4:  Cost:     0.0047, Accuracy:  0.744000
# Epoch 51, CIFAR-10 Batch 5:  Cost:     0.0051, Accuracy:  0.730600
# Epoch 52, CIFAR-10 Batch 1:  Cost:     0.0040, Accuracy:  0.745000
# Epoch 52, CIFAR-10 Batch 2:  Cost:     0.0037, Accuracy:  0.741400
# Epoch 52, CIFAR-10 Batch 3:  Cost:     0.0030, Accuracy:  0.736200
# Epoch 52, CIFAR-10 Batch 4:  Cost:     0.0039, Accuracy:  0.741800
# Epoch 52, CIFAR-10 Batch 5:  Cost:     0.0030, Accuracy:  0.741200
# Epoch 53, CIFAR-10 Batch 1:  Cost:     0.0046, Accuracy:  0.741000
# Epoch 53, CIFAR-10 Batch 2:  Cost:     0.0020, Accuracy:  0.747600
# Epoch 53, CIFAR-10 Batch 3:  Cost:     0.0054, Accuracy:  0.739200
# Epoch 53, CIFAR-10 Batch 4:  Cost:     0.0049, Accuracy:  0.740000
# Epoch 53, CIFAR-10 Batch 5:  Cost:     0.0070, Accuracy:  0.735800
# Epoch 54, CIFAR-10 Batch 1:  Cost:     0.0033, Accuracy:  0.741000
# Epoch 54, CIFAR-10 Batch 2:  Cost:     0.0044, Accuracy:  0.744600
# Epoch 54, CIFAR-10 Batch 3:  Cost:     0.0035, Accuracy:  0.737000
# Epoch 54, CIFAR-10 Batch 4:  Cost:     0.0024, Accuracy:  0.737400
# Epoch 54, CIFAR-10 Batch 5:  Cost:     0.0042, Accuracy:  0.731800
# Epoch 55, CIFAR-10 Batch 1:  Cost:     0.0027, Accuracy:  0.745600
# Epoch 55, CIFAR-10 Batch 2:  Cost:     0.0025, Accuracy:  0.749000
# Epoch 55, CIFAR-10 Batch 3:  Cost:     0.0059, Accuracy:  0.728600
# Epoch 55, CIFAR-10 Batch 4:  Cost:     0.0027, Accuracy:  0.749600
# Epoch 55, CIFAR-10 Batch 5:  Cost:     0.0039, Accuracy:  0.740200
# Epoch 56, CIFAR-10 Batch 1:  Cost:     0.0018, Accuracy:  0.743800
# Epoch 56, CIFAR-10 Batch 2:  Cost:     0.0034, Accuracy:  0.739600
# Epoch 56, CIFAR-10 Batch 3:  Cost:     0.0037, Accuracy:  0.737400
# Epoch 56, CIFAR-10 Batch 4:  Cost:     0.0022, Accuracy:  0.743800
# Epoch 56, CIFAR-10 Batch 5:  Cost:     0.0036, Accuracy:  0.739200
# Epoch 57, CIFAR-10 Batch 1:  Cost:     0.0024, Accuracy:  0.741400
# Epoch 57, CIFAR-10 Batch 2:  Cost:     0.0041, Accuracy:  0.732000
# Epoch 57, CIFAR-10 Batch 3:  Cost:     0.0039, Accuracy:  0.735000
# Epoch 57, CIFAR-10 Batch 4:  Cost:     0.0020, Accuracy:  0.743600
# Epoch 57, CIFAR-10 Batch 5:  Cost:     0.0034, Accuracy:  0.738800
# Epoch 58, CIFAR-10 Batch 1:  Cost:     0.0019, Accuracy:  0.743400
# Epoch 58, CIFAR-10 Batch 2:  Cost:     0.0019, Accuracy:  0.746000
# Epoch 58, CIFAR-10 Batch 3:  Cost:     0.0034, Accuracy:  0.736000
# Epoch 58, CIFAR-10 Batch 4:  Cost:     0.0016, Accuracy:  0.742000
# Epoch 58, CIFAR-10 Batch 5:  Cost:     0.0023, Accuracy:  0.742000
# Epoch 59, CIFAR-10 Batch 1:  Cost:     0.0026, Accuracy:  0.743200
# Epoch 59, CIFAR-10 Batch 2:  Cost:     0.0028, Accuracy:  0.743800
# Epoch 59, CIFAR-10 Batch 3:  Cost:     0.0033, Accuracy:  0.722400
# Epoch 59, CIFAR-10 Batch 4:  Cost:     0.0025, Accuracy:  0.741600
# Epoch 59, CIFAR-10 Batch 5:  Cost:     0.0030, Accuracy:  0.734800
# Epoch 60, CIFAR-10 Batch 1:  Cost:     0.0029, Accuracy:  0.732600
# Epoch 60, CIFAR-10 Batch 2:  Cost:     0.0028, Accuracy:  0.742400
# Epoch 60, CIFAR-10 Batch 3:  Cost:     0.0035, Accuracy:  0.725400
# Epoch 60, CIFAR-10 Batch 4:  Cost:     0.0031, Accuracy:  0.738000
# Epoch 60, CIFAR-10 Batch 5:  Cost:     0.0036, Accuracy:  0.732400
# Epoch 61, CIFAR-10 Batch 1:  Cost:     0.0049, Accuracy:  0.740800
# Epoch 61, CIFAR-10 Batch 2:  Cost:     0.0051, Accuracy:  0.742400
# Epoch 61, CIFAR-10 Batch 3:  Cost:     0.0023, Accuracy:  0.725200
# Epoch 61, CIFAR-10 Batch 4:  Cost:     0.0016, Accuracy:  0.749600
# Epoch 61, CIFAR-10 Batch 5:  Cost:     0.0020, Accuracy:  0.738200
# Epoch 62, CIFAR-10 Batch 1:  Cost:     0.0041, Accuracy:  0.732200
# Epoch 62, CIFAR-10 Batch 2:  Cost:     0.0026, Accuracy:  0.740600
# Epoch 62, CIFAR-10 Batch 3:  Cost:     0.0030, Accuracy:  0.730600
# Epoch 62, CIFAR-10 Batch 4:  Cost:     0.0027, Accuracy:  0.742800
# Epoch 62, CIFAR-10 Batch 5:  Cost:     0.0018, Accuracy:  0.740000
# Epoch 63, CIFAR-10 Batch 1:  Cost:     0.0023, Accuracy:  0.739800
# Epoch 63, CIFAR-10 Batch 2:  Cost:     0.0014, Accuracy:  0.750200
# Epoch 63, CIFAR-10 Batch 3:  Cost:     0.0037, Accuracy:  0.718400
# Epoch 63, CIFAR-10 Batch 4:  Cost:     0.0018, Accuracy:  0.738800
# Epoch 63, CIFAR-10 Batch 5:  Cost:     0.0016, Accuracy:  0.740800
# Epoch 64, CIFAR-10 Batch 1:  Cost:     0.0015, Accuracy:  0.736600
# Epoch 64, CIFAR-10 Batch 2:  Cost:     0.0026, Accuracy:  0.744400
# Epoch 64, CIFAR-10 Batch 3:  Cost:     0.0044, Accuracy:  0.723200
# Epoch 64, CIFAR-10 Batch 4:  Cost:     0.0019, Accuracy:  0.735000
# Epoch 64, CIFAR-10 Batch 5:  Cost:     0.0020, Accuracy:  0.737000
# Epoch 65, CIFAR-10 Batch 1:  Cost:     0.0017, Accuracy:  0.741200
# Epoch 65, CIFAR-10 Batch 2:  Cost:     0.0025, Accuracy:  0.748200
# Epoch 65, CIFAR-10 Batch 3:  Cost:     0.0018, Accuracy:  0.734400
# Epoch 65, CIFAR-10 Batch 4:  Cost:     0.0010, Accuracy:  0.745800
# Epoch 65, CIFAR-10 Batch 5:  Cost:     0.0011, Accuracy:  0.736200
# Epoch 66, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.743600
# Epoch 66, CIFAR-10 Batch 2:  Cost:     0.0018, Accuracy:  0.746800
# Epoch 66, CIFAR-10 Batch 3:  Cost:     0.0020, Accuracy:  0.732000
# Epoch 66, CIFAR-10 Batch 4:  Cost:     0.0011, Accuracy:  0.742200
# Epoch 66, CIFAR-10 Batch 5:  Cost:     0.0014, Accuracy:  0.741400
# Epoch 67, CIFAR-10 Batch 1:  Cost:     0.0012, Accuracy:  0.747800
# Epoch 67, CIFAR-10 Batch 2:  Cost:     0.0014, Accuracy:  0.745400
# Epoch 67, CIFAR-10 Batch 3:  Cost:     0.0022, Accuracy:  0.725600
# Epoch 67, CIFAR-10 Batch 4:  Cost:     0.0018, Accuracy:  0.742000
# Epoch 67, CIFAR-10 Batch 5:  Cost:     0.0019, Accuracy:  0.737000
# Epoch 68, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.745400
# Epoch 68, CIFAR-10 Batch 2:  Cost:     0.0013, Accuracy:  0.747000
# Epoch 68, CIFAR-10 Batch 3:  Cost:     0.0031, Accuracy:  0.728800
# Epoch 68, CIFAR-10 Batch 4:  Cost:     0.0032, Accuracy:  0.738800
# Epoch 68, CIFAR-10 Batch 5:  Cost:     0.0023, Accuracy:  0.735800
# Epoch 69, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.749800
# Epoch 69, CIFAR-10 Batch 2:  Cost:     0.0021, Accuracy:  0.748200
# Epoch 69, CIFAR-10 Batch 3:  Cost:     0.0015, Accuracy:  0.732200
# Epoch 69, CIFAR-10 Batch 4:  Cost:     0.0019, Accuracy:  0.732800
# Epoch 69, CIFAR-10 Batch 5:  Cost:     0.0024, Accuracy:  0.723400
# Epoch 70, CIFAR-10 Batch 1:  Cost:     0.0012, Accuracy:  0.738200
# Epoch 70, CIFAR-10 Batch 2:  Cost:     0.0011, Accuracy:  0.742600
# Epoch 70, CIFAR-10 Batch 3:  Cost:     0.0019, Accuracy:  0.739200
# Epoch 70, CIFAR-10 Batch 4:  Cost:     0.0018, Accuracy:  0.742800
# Epoch 70, CIFAR-10 Batch 5:  Cost:     0.0013, Accuracy:  0.739000
# Epoch 71, CIFAR-10 Batch 1:  Cost:     0.0020, Accuracy:  0.741200
# Epoch 71, CIFAR-10 Batch 2:  Cost:     0.0012, Accuracy:  0.736600
# Epoch 71, CIFAR-10 Batch 3:  Cost:     0.0063, Accuracy:  0.730000
# Epoch 71, CIFAR-10 Batch 4:  Cost:     0.0048, Accuracy:  0.728000
# Epoch 71, CIFAR-10 Batch 5:  Cost:     0.0015, Accuracy:  0.728400
# Epoch 72, CIFAR-10 Batch 1:  Cost:     0.0017, Accuracy:  0.735400
# Epoch 72, CIFAR-10 Batch 2:  Cost:     0.0013, Accuracy:  0.734400
# Epoch 72, CIFAR-10 Batch 3:  Cost:     0.0014, Accuracy:  0.735600
# Epoch 72, CIFAR-10 Batch 4:  Cost:     0.0017, Accuracy:  0.740600
# Epoch 72, CIFAR-10 Batch 5:  Cost:     0.0009, Accuracy:  0.742600
# Epoch 73, CIFAR-10 Batch 1:  Cost:     0.0019, Accuracy:  0.748200
# Epoch 73, CIFAR-10 Batch 2:  Cost:     0.0009, Accuracy:  0.747200
# Epoch 73, CIFAR-10 Batch 3:  Cost:     0.0008, Accuracy:  0.729200
# Epoch 73, CIFAR-10 Batch 4:  Cost:     0.0014, Accuracy:  0.735000
# Epoch 73, CIFAR-10 Batch 5:  Cost:     0.0011, Accuracy:  0.737600
# Epoch 74, CIFAR-10 Batch 1:  Cost:     0.0013, Accuracy:  0.736800
# Epoch 74, CIFAR-10 Batch 2:  Cost:     0.0006, Accuracy:  0.744600
# Epoch 74, CIFAR-10 Batch 3:  Cost:     0.0011, Accuracy:  0.723400
# Epoch 74, CIFAR-10 Batch 4:  Cost:     0.0010, Accuracy:  0.744200
# Epoch 74, CIFAR-10 Batch 5:  Cost:     0.0012, Accuracy:  0.739600
# Epoch 75, CIFAR-10 Batch 1:  Cost:     0.0011, Accuracy:  0.740600
# Epoch 75, CIFAR-10 Batch 2:  Cost:     0.0014, Accuracy:  0.747200
# Epoch 75, CIFAR-10 Batch 3:  Cost:     0.0007, Accuracy:  0.734200
# Epoch 75, CIFAR-10 Batch 4:  Cost:     0.0014, Accuracy:  0.742200
# Epoch 75, CIFAR-10 Batch 5:  Cost:     0.0007, Accuracy:  0.737600
# Epoch 76, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.746600
# Epoch 76, CIFAR-10 Batch 2:  Cost:     0.0007, Accuracy:  0.750800
# Epoch 76, CIFAR-10 Batch 3:  Cost:     0.0011, Accuracy:  0.731000
# Epoch 76, CIFAR-10 Batch 4:  Cost:     0.0010, Accuracy:  0.741800
# Epoch 76, CIFAR-10 Batch 5:  Cost:     0.0009, Accuracy:  0.739000
# Epoch 77, CIFAR-10 Batch 1:  Cost:     0.0014, Accuracy:  0.744800
# Epoch 77, CIFAR-10 Batch 2:  Cost:     0.0011, Accuracy:  0.738000
# Epoch 77, CIFAR-10 Batch 3:  Cost:     0.0014, Accuracy:  0.736200
# Epoch 77, CIFAR-10 Batch 4:  Cost:     0.0017, Accuracy:  0.740200
# Epoch 77, CIFAR-10 Batch 5:  Cost:     0.0008, Accuracy:  0.742000
# Epoch 78, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.749000
# Epoch 78, CIFAR-10 Batch 2:  Cost:     0.0009, Accuracy:  0.744600
# Epoch 78, CIFAR-10 Batch 3:  Cost:     0.0014, Accuracy:  0.734800
# Epoch 78, CIFAR-10 Batch 4:  Cost:     0.0012, Accuracy:  0.738200
# Epoch 78, CIFAR-10 Batch 5:  Cost:     0.0007, Accuracy:  0.741200
# Epoch 79, CIFAR-10 Batch 1:  Cost:     0.0024, Accuracy:  0.739000
# Epoch 79, CIFAR-10 Batch 2:  Cost:     0.0011, Accuracy:  0.746400
# Epoch 79, CIFAR-10 Batch 3:  Cost:     0.0008, Accuracy:  0.733400
# Epoch 79, CIFAR-10 Batch 4:  Cost:     0.0012, Accuracy:  0.737000
# Epoch 79, CIFAR-10 Batch 5:  Cost:     0.0010, Accuracy:  0.737000
# Epoch 80, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.742400
# Epoch 80, CIFAR-10 Batch 2:  Cost:     0.0011, Accuracy:  0.741400
# Epoch 80, CIFAR-10 Batch 3:  Cost:     0.0011, Accuracy:  0.734400
# Epoch 80, CIFAR-10 Batch 4:  Cost:     0.0011, Accuracy:  0.736600
# Epoch 80, CIFAR-10 Batch 5:  Cost:     0.0015, Accuracy:  0.734400
# Epoch 81, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.738200
# Epoch 81, CIFAR-10 Batch 2:  Cost:     0.0009, Accuracy:  0.741200
# Epoch 81, CIFAR-10 Batch 3:  Cost:     0.0010, Accuracy:  0.730200
# Epoch 81, CIFAR-10 Batch 4:  Cost:     0.0012, Accuracy:  0.736000
# Epoch 81, CIFAR-10 Batch 5:  Cost:     0.0011, Accuracy:  0.745800
# Epoch 82, CIFAR-10 Batch 1:  Cost:     0.0006, Accuracy:  0.746000
# Epoch 82, CIFAR-10 Batch 2:  Cost:     0.0021, Accuracy:  0.737200
# Epoch 82, CIFAR-10 Batch 3:  Cost:     0.0025, Accuracy:  0.718200
# Epoch 82, CIFAR-10 Batch 4:  Cost:     0.0020, Accuracy:  0.732600
# Epoch 82, CIFAR-10 Batch 5:  Cost:     0.0012, Accuracy:  0.727000
# Epoch 83, CIFAR-10 Batch 1:  Cost:     0.0031, Accuracy:  0.744000
# Epoch 83, CIFAR-10 Batch 2:  Cost:     0.0034, Accuracy:  0.733800
# Epoch 83, CIFAR-10 Batch 3:  Cost:     0.0019, Accuracy:  0.741800
# Epoch 83, CIFAR-10 Batch 4:  Cost:     0.0021, Accuracy:  0.739200
# Epoch 83, CIFAR-10 Batch 5:  Cost:     0.0006, Accuracy:  0.737600
# Epoch 84, CIFAR-10 Batch 1:  Cost:     0.0005, Accuracy:  0.741000
# Epoch 84, CIFAR-10 Batch 2:  Cost:     0.0010, Accuracy:  0.743400
# Epoch 84, CIFAR-10 Batch 3:  Cost:     0.0024, Accuracy:  0.738400
# Epoch 84, CIFAR-10 Batch 4:  Cost:     0.0011, Accuracy:  0.741600
# Epoch 84, CIFAR-10 Batch 5:  Cost:     0.0010, Accuracy:  0.742400
# Epoch 85, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.743400
# Epoch 85, CIFAR-10 Batch 2:  Cost:     0.0006, Accuracy:  0.740600
# Epoch 85, CIFAR-10 Batch 3:  Cost:     0.0012, Accuracy:  0.735200
# Epoch 85, CIFAR-10 Batch 4:  Cost:     0.0021, Accuracy:  0.726600
# Epoch 85, CIFAR-10 Batch 5:  Cost:     0.0009, Accuracy:  0.740200
# Epoch 86, CIFAR-10 Batch 1:  Cost:     0.0007, Accuracy:  0.741200
# Epoch 86, CIFAR-10 Batch 2:  Cost:     0.0008, Accuracy:  0.740800
# Epoch 86, CIFAR-10 Batch 3:  Cost:     0.0014, Accuracy:  0.733400
# Epoch 86, CIFAR-10 Batch 4:  Cost:     0.0007, Accuracy:  0.736000
# Epoch 86, CIFAR-10 Batch 5:  Cost:     0.0011, Accuracy:  0.744400
# Epoch 87, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.743400
# Epoch 87, CIFAR-10 Batch 2:  Cost:     0.0005, Accuracy:  0.741600
# Epoch 87, CIFAR-10 Batch 3:  Cost:     0.0008, Accuracy:  0.740200
# Epoch 87, CIFAR-10 Batch 4:  Cost:     0.0011, Accuracy:  0.730800
# Epoch 87, CIFAR-10 Batch 5:  Cost:     0.0005, Accuracy:  0.737200
# Epoch 88, CIFAR-10 Batch 1:  Cost:     0.0005, Accuracy:  0.745200
# Epoch 88, CIFAR-10 Batch 2:  Cost:     0.0007, Accuracy:  0.740200
# Epoch 88, CIFAR-10 Batch 3:  Cost:     0.0011, Accuracy:  0.737600
# Epoch 88, CIFAR-10 Batch 4:  Cost:     0.0007, Accuracy:  0.736400
# Epoch 88, CIFAR-10 Batch 5:  Cost:     0.0005, Accuracy:  0.736800
# Epoch 89, CIFAR-10 Batch 1:  Cost:     0.0006, Accuracy:  0.740200
# Epoch 89, CIFAR-10 Batch 2:  Cost:     0.0010, Accuracy:  0.732200
# Epoch 89, CIFAR-10 Batch 3:  Cost:     0.0006, Accuracy:  0.732600
# Epoch 89, CIFAR-10 Batch 4:  Cost:     0.0009, Accuracy:  0.732400
# Epoch 89, CIFAR-10 Batch 5:  Cost:     0.0004, Accuracy:  0.738400
# Epoch 90, CIFAR-10 Batch 1:  Cost:     0.0008, Accuracy:  0.736400
# Epoch 90, CIFAR-10 Batch 2:  Cost:     0.0005, Accuracy:  0.735600
# Epoch 90, CIFAR-10 Batch 3:  Cost:     0.0011, Accuracy:  0.720400
# Epoch 90, CIFAR-10 Batch 4:  Cost:     0.0005, Accuracy:  0.738000
# Epoch 90, CIFAR-10 Batch 5:  Cost:     0.0004, Accuracy:  0.732600
# Epoch 91, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.742800
# Epoch 91, CIFAR-10 Batch 2:  Cost:     0.0011, Accuracy:  0.731200
# Epoch 91, CIFAR-10 Batch 3:  Cost:     0.0010, Accuracy:  0.734200
# Epoch 91, CIFAR-10 Batch 4:  Cost:     0.0015, Accuracy:  0.721000
# Epoch 91, CIFAR-10 Batch 5:  Cost:     0.0005, Accuracy:  0.738800
# Epoch 92, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.743200
# Epoch 92, CIFAR-10 Batch 2:  Cost:     0.0006, Accuracy:  0.739000
# Epoch 92, CIFAR-10 Batch 3:  Cost:     0.0015, Accuracy:  0.728400
# Epoch 92, CIFAR-10 Batch 4:  Cost:     0.0011, Accuracy:  0.735200
# Epoch 92, CIFAR-10 Batch 5:  Cost:     0.0004, Accuracy:  0.738000
# Epoch 93, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.740200
# Epoch 93, CIFAR-10 Batch 2:  Cost:     0.0004, Accuracy:  0.741200
# Epoch 93, CIFAR-10 Batch 3:  Cost:     0.0006, Accuracy:  0.727200
# Epoch 93, CIFAR-10 Batch 4:  Cost:     0.0007, Accuracy:  0.732400
# Epoch 93, CIFAR-10 Batch 5:  Cost:     0.0003, Accuracy:  0.730600
# Epoch 94, CIFAR-10 Batch 1:  Cost:     0.0010, Accuracy:  0.738800
# Epoch 94, CIFAR-10 Batch 2:  Cost:     0.0010, Accuracy:  0.730800
# Epoch 94, CIFAR-10 Batch 3:  Cost:     0.0004, Accuracy:  0.729400
# Epoch 94, CIFAR-10 Batch 4:  Cost:     0.0008, Accuracy:  0.732000
# Epoch 94, CIFAR-10 Batch 5:  Cost:     0.0014, Accuracy:  0.736400
# Epoch 95, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.740000
# Epoch 95, CIFAR-10 Batch 2:  Cost:     0.0009, Accuracy:  0.727800
# Epoch 95, CIFAR-10 Batch 3:  Cost:     0.0005, Accuracy:  0.731200
# Epoch 95, CIFAR-10 Batch 4:  Cost:     0.0005, Accuracy:  0.733200
# Epoch 95, CIFAR-10 Batch 5:  Cost:     0.0006, Accuracy:  0.735200
# Epoch 96, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.736200
# Epoch 96, CIFAR-10 Batch 2:  Cost:     0.0005, Accuracy:  0.743000
# Epoch 96, CIFAR-10 Batch 3:  Cost:     0.0009, Accuracy:  0.729800
# Epoch 96, CIFAR-10 Batch 4:  Cost:     0.0004, Accuracy:  0.738000
# Epoch 96, CIFAR-10 Batch 5:  Cost:     0.0018, Accuracy:  0.741400
# Epoch 97, CIFAR-10 Batch 1:  Cost:     0.0006, Accuracy:  0.743400
# Epoch 97, CIFAR-10 Batch 2:  Cost:     0.0005, Accuracy:  0.738200
# Epoch 97, CIFAR-10 Batch 3:  Cost:     0.0028, Accuracy:  0.717800
# Epoch 97, CIFAR-10 Batch 4:  Cost:     0.0004, Accuracy:  0.734200
# Epoch 97, CIFAR-10 Batch 5:  Cost:     0.0007, Accuracy:  0.738000
# Epoch 98, CIFAR-10 Batch 1:  Cost:     0.0003, Accuracy:  0.742600
# Epoch 98, CIFAR-10 Batch 2:  Cost:     0.0002, Accuracy:  0.742400
# Epoch 98, CIFAR-10 Batch 3:  Cost:     0.0004, Accuracy:  0.734200
# Epoch 98, CIFAR-10 Batch 4:  Cost:     0.0008, Accuracy:  0.738400
# Epoch 98, CIFAR-10 Batch 5:  Cost:     0.0006, Accuracy:  0.742800
# Epoch 99, CIFAR-10 Batch 1:  Cost:     0.0004, Accuracy:  0.745000
# Epoch 99, CIFAR-10 Batch 2:  Cost:     0.0004, Accuracy:  0.741200
# Epoch 99, CIFAR-10 Batch 3:  Cost:     0.0003, Accuracy:  0.732000
# Epoch 99, CIFAR-10 Batch 4:  Cost:     0.0004, Accuracy:  0.742200
# Epoch 99, CIFAR-10 Batch 5:  Cost:     0.0005, Accuracy:  0.740800
# Epoch 100, CIFAR-10 Batch 1:  Cost:     0.0016, Accuracy:  0.726200
# Epoch 100, CIFAR-10 Batch 2:  Cost:     0.0002, Accuracy:  0.744600
# Epoch 100, CIFAR-10 Batch 3:  Cost:     0.0015, Accuracy:  0.730200
# Epoch 100, CIFAR-10 Batch 4:  Cost:     0.0003, Accuracy:  0.737400
# Epoch 100, CIFAR-10 Batch 5:  Cost:     0.0003, Accuracy:  0.739200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7308364003896713

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
